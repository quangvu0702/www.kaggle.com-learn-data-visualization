# %% [markdown]
# ## Set up env and import seaborn

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
ls data/
# Out:
# fifa.csv  fifa_variable_information.csv

# %%
# Path of the file to read
fifa_filepath = "data/fifa.csv"

# %%
# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %%
fifa_data[0:3]
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0

# %%
type(fifa_data); fifa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 286 entries, 1993-08-08 to 2018-06-07
# Data columns (total 6 columns):
# ARG    286 non-null float64
# BRA    286 non-null float64
# ESP    286 non-null float64
# FRA    286 non-null float64
# GER    286 non-null float64
# ITA    286 non-null float64
# dtypes: float64(6)
# memory usage: 15.6 KB

# %% [markdown]
# ### One line of code to make chart

# %%
# set width and height
plt.figure(figsize=(16, 6))
sns.lineplot(data=fifa_data)

# %%
spotify_data = pd.read_csv('data/spotify.csv', index_col='Date', parse_dates=True)

# %%
sns.lineplot(data=spotify_data)

# %%
plt.figure(figsize=(16,6))
plt.title("Daily Global Strams of Popular Songs in 2017-2018")
print(list(spotify_data.columns))
sns.lineplot(data=spotify_data['Shape of You'], label='Shape of You')
sns.lineplot(data=spotify_data['HUMBLE.'], label='HUMBLE.')
# Out:
# ['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.', 'Unforgettable']
